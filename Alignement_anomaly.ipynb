# %%
# %%capture
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 20, 15
from IPython.display import display, Math, Latex
# %pylab inline

# %%
# %run Alignement_2_3.py

# %%
map_comm = hp.read_map("dx11_v2_commander_int_cmb_005a_2048.fits")
# Out:
# NSIDE = 2048
# ORDERING = RING in fits file

# %%
alm_comm = hp.map2alm(map_comm,100)

# %%
sim_tot = np.load("Outputs/and_disp_ell_dep_12_14000sim.npy")

# %%
aad_comm =[]

# %%
for ell in range(3,12+1):
    aad_comm.append(min(get_angular_mean_disp(alm_comm,ell)))

# %%
plot_stat_ell_dep_curve(sim_tot,aad_comm)

# %%
plot_stat_ell_dep_hist(sim_tot,aad_comm)

# %%
plot_first_multipoles(map_comm,16,13)

# %%
plot_scal_prod(50,map_comm, "Commander")

# %%
plt.xticks?
